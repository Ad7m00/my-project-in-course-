# %%
# !pip install pandas
# !pip install yfinance
# !pip install bs4
# !pip install html5lib
# !pip install lxml

# %%
import pandas as pd
import yfinance as yf
import requests 
import bs4 as BeautifulSoup

# %%
tick = "TSLA"

# %%
yf.download(tick)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-03-27  181.410004  181.910004  176.000000  179.830002  179.830002
# 2024-03-28  177.449997  179.570007  175.300003  175.789993  175.789993
# 2024-04-01  176.169998  176.750000  170.210007  175.220001  175.220001
# 2024-04-02  164.750000  167.690002  163.429993  166.630005  166.630005
# 2024-04-03  164.020004  168.820007  163.279999  168.380005  168.380005
#
#                Volume
# Date
# ...

# %%
Tesla= yf.download(tick)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
Tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-03-28  177.449997  179.570007  175.300003  175.789993  175.789993
# 2024-04-01  176.169998  176.750000  170.210007  175.220001  175.220001
# 2024-04-02  164.750000  167.690002  163.429993  166.630005  166.630005
# 2024-04-03  164.020004  168.820007  163.279999  168.380005  168.380005
# 2024-04-04  170.000000  177.190002  168.009995  171.009995  171.009995
#
#                Volume
# Date
# 2024-03-28   77654800
# 2024-04-01   81562100
# 2024-04-02  116650600
# 2024-04-03   82578000
# 2024-04-04  110924639

# %%
Tesla_share_price_data = Tesla.history(period="max")
print=(Tesla_share_price_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3012\623108108.py in ?()
# ----> 1 Tesla_share_price_data = Tesla.history(period="max")
#       2 print=(Tesla_share_price_data)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'history'

# %%
Tesla.reset_index(inplace=True)

# %%
Tesla.plot(x="Date", y="Adj Close")
# Out:
# <Axes: xlabel='Date'>

# %%
tick = "GME"

# %%
yf.download(tick)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2002-02-13   2.40625   2.51500   2.38125   2.51250   1.691667  76216000
# 2002-02-14   2.54375   2.54875   2.48125   2.50000   1.683250  11021600
# 2002-02-15   2.50000   2.50625   2.46250   2.48750   1.674834   8389600
# 2002-02-19   2.47500   2.47500   2.34375   2.38750   1.607504   7410400
# 2002-02-20   2.40000   2.46875   2.38125   2.46875   1.662210   6892800
# ...              ...       ...       ...       ...        ...       ...
# 2024-03-27  13.05000  13.72000  12.80000  13.17000  13.170000  17871300
# 2024-03-28  13.19000  13.19000  12.47000  12.52000  12.520000   8473500
# 2024-04-01  12.63000  12.67000  11.55000  11.99000  11.990000   9207100
# 2024-04-02  11.84000  11.99000  11.26000  11.28000  11.280000   6327700
# 2024-04-03  11.22000  11.50000  10.90000  11.38000  11.380000   4320600
#
# [5572 rows x 6 columns]

# %%
gme=yf.download(tick)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
gme.head()
# Out:
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2002-02-13  2.40625  2.51500  2.38125  2.51250   1.691666  76216000
# 2002-02-14  2.54375  2.54875  2.48125  2.50000   1.683250  11021600
# 2002-02-15  2.50000  2.50625  2.46250  2.48750   1.674834   8389600
# 2002-02-19  2.47500  2.47500  2.34375  2.38750   1.607504   7410400
# 2002-02-20  2.40000  2.46875  2.38125  2.46875   1.662210   6892800

# %%
gme.tail()
# Out:
#              Open    High      Low   Close  Adj Close   Volume
# Date
# 2024-03-28  13.19  13.190  12.4700  12.520     12.520  8473500
# 2024-04-01  12.63  12.670  11.5500  11.990     11.990  9207100
# 2024-04-02  11.84  11.990  11.2600  11.280     11.280  6327700
# 2024-04-03  11.22  11.500  10.9000  11.380     11.380  4320600
# 2024-04-04  11.50  11.825  11.3799  11.585     11.585  3563107

# %%
tt= gme.download(period="max") 
print=(tt)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3012\1361900773.py in ?()
# ----> 1 tt= gme.download(period="max")
#       2 print=(tt)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'download'

# %%
gme.reset_index(inplace=True)

# %%
gme.plot(x="Date", y="Adj Close")
# Out:
# <Axes: xlabel='Date'>
